# %% [markdown]
# ## This notebook is only used to download the Kaggle dataset. It is not part of the main pipeline.

# %% [markdown]
# ### Data Download Helper
#
# This notebook is provided as a helper to download the Kaggle ESG dataset
# and place it in the correct directory (`data/raw/`).
#
# It is **not required** to run the project.
# The main pipeline can be executed directly using:
#
# python main.py

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import kagglehub

np.random.seed(42) #reproductible results 

#Directory 
BASE_DIR = Path("..").resolve()
DATA_DIR = BASE_DIR / "data"
RAW_DIR = DATA_DIR / "raw"
PROC_DIR = DATA_DIR / "processed"

RAW_DIR.mkdir(parents=True, exist_ok=True)
PROC_DIR.mkdir(parents=True, exist_ok=True)

BASE_DIR, RAW_DIR, PROC_DIR
# Out:
# (PosixPath('/files/project-DSAP'),
#  PosixPath('/files/project-DSAP/data/raw'),
#  PosixPath('/files/project-DSAP/data/processed'))

# %%
#Kaggle dataset
# Download latest version
path = kagglehub.dataset_download("pritish509/s-and-p-500-esg-risk-ratings")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /home/datahub/.cache/kagglehub/datasets/pritish509/s-and-p-500-esg-risk-ratings/versions/2

# %%
#File csv name 
from pathlib import Path

# the path of  kagglehub.dataset_download
src_dir = Path(path)

# list of the files in this directory
for p in src_dir.iterdir():
    print(p.name)
# Out:
# SP 500 ESG Risk Ratings.csv

# %%
from shutil import copy2

BASE_DIR = Path("..").resolve()
DATA_DIR = BASE_DIR / "data"
RAW_DIR = DATA_DIR / "raw"

RAW_DIR.mkdir(parents=True, exist_ok=True)


csv_src = src_dir / "SP 500 ESG Risk Ratings.csv"
csv_dst = RAW_DIR / "esg_risk_ratings.csv"  #change name
copy2(csv_src, csv_dst)

csv_dst, csv_dst.exists()
# Out:
# (PosixPath('/files/project-DSAP/data/raw/esg_risk_ratings.csv'), True)
